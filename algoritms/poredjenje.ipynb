# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

bf_n  = [4, 7, 10, 30]
bf_t  = [0.0012, 0.0252, 0.6416, 300.0014]

greedy_n  = [4,7,30,50,100,200,250,350,450,550,1000,3000,5000]
greedy_t  = [0.0003,0.0003,0.0008,0.0014,0.0066,0.0152,0.0244,0.0521,0.0733,0.0758,0.2577,2.9644,4.9291]
greedy_sorted_t = [0.0002,0.0002,0.0006,0.0009,0.0024,0.0135,0.0263,0.0288,0.0606,0.0771,0.2379,2.3567,5.5181]

ga_n = [4, 7,30,50,100,200,250,350]
ga_t = [0.1894,0.2231,0.9192,2.0037,7.4947,32.0654,41.6805,103.7946]  

sa_n = [4, 7,30,50,100,200,250,350,450,550,1000]
sa_t = [0.0328,0.0332,0.1104,0.1901,0.6824,3.6023,4.1755,9.2947,16.4635,28.1687,97.9570]

# %%
plt.figure(figsize=(9,5))
plt.plot(bf_n, bf_t, marker='o', label='Brute-force')
plt.plot(greedy_n, greedy_t, marker='o', label='Greedy (basic)')
plt.plot(greedy_n, greedy_sorted_t, marker='s', label='Greedy (sorted)')
plt.plot(ga_n, ga_t, marker='^', label='GA')
plt.plot(sa_n, sa_t, marker='v', label='SA')


plt.xlabel('Broj čvorova (n)')
plt.ylabel('Vreme (s) ')
plt.title('Poređenje vremena izvršavanja')
plt.grid(True, which='both', ls='--', alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()
